# %%
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation
import folium #for creating maps
import requests #for retreiving Information
from geopy.geocoders import Nominatim #converting address to cordinates
from pandas.io.json import json_normalize #converting json to DataFrame

# %%
CLIENT_ID = 'G4UVNIL45OY0AOYORGM32K1DCGLRSNNO5LNQMEWUVIRW4VU2' # your Foursquare ID
CLIENT_SECRET = 'J5ZSJAQ5RDEOJDHBZWGHLJI4EE4OII4XAVDD3H51DCA3YFKF' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: G4UVNIL45OY0AOYORGM32K1DCGLRSNNO5LNQMEWUVIRW4VU2
# CLIENT_SECRET:J5ZSJAQ5RDEOJDHBZWGHLJI4EE4OII4XAVDD3H51DCA3YFKF

# %%
address = '1151 South Forest Avenue, Tempe, AZ 85281'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 33.41697155 -111.93624619348861

# %%
search_query = 'Mexican'
radius = 2000
print(search_query + ' .... OK!')
# Out:
# Mexican .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=G4UVNIL45OY0AOYORGM32K1DCGLRSNNO5LNQMEWUVIRW4VU2&client_secret=J5ZSJAQ5RDEOJDHBZWGHLJI4EE4OII4XAVDD3H51DCA3YFKF&ll=33.41697155,-111.93624619348861&v=20180604&query=Mexican&radius=2000&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5f27653085d1da39f95e1ef5'},
#  'response': {'venues': [{'id': '4aa6f5a8f964a520a34b20e3',
#     'name': 'Chipotle Mexican Grill',
#     'location': {'address': '1038 S Mill Ave',
#      'crossStreet': 'at W 11th St',
#      'lat': 33.41798133570578,
#      'lng': -111.94040165583704,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.41798133570578,
#        'lng': -111.94040165583704},
#       {'label': 'entrance', 'lat': 33.418009, 'lng': -111.940346}],
#      'distance': 402,
#      'postalCode': '85281',
#      'cc': 'US',
#      'city': 'Tempe',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['1038 S Mill Ave (at W 11th St)',
#       'Tempe, AZ 85281',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c1941735',
#       'name': 'Mexican Restaurant',
#       'pluralName': 'Mexican Restaurants',
#       'shortName': 'Mexican',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1596417410',
#     'hasPerk': False},
#    {'id': '4ad76fe1f964a520670a21e3',
#     'name': "Rosita's Fine Mexican Food",
#     'location': {'address': '960 W University Dr',
#      'crossStreet': 'at Hardy Dr',
#      'lat': 33.42258153193346,
#      'lng': -111.9517391060788,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.42258153193346,
#        'lng': -111.9517391060788}],
#      'distance': 1569,
#      'postalCode': '85281',
#      'cc': 'US',
#      'city': 'Tempe',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['960 W University Dr (at Hardy Dr)',
#       'Tempe, AZ 85281',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c1941735',
#       'name': 'Mexican Restaurant',
#       'pluralName': 'Mexican Restaurants',
#       'shortName': 'Mexican',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1596417410',
#     'hasPerk': False},
#    {'id': '4b6ccb12f964a520e3542ce3',
#     'name': "Filiberto's Mexican Food",
#     'location': {'address': '1250 West Broadway Road',
#      'crossStreet': 'at S Cutler Dr',
#      'lat': 33.40780775,
#      'lng': -111.95789026,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.40780775,
#        'lng': -111.95789026}],
#      'distance': 2255,
#      'postalCode': '85282',
#      'cc': 'US',
#      'city': 'Tempe',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['1250 West Broadway Road (at S Cutler Dr)',
#       'Tempe, AZ 85282',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c1941735',
#       'name': 'Mexican Restaurant',
#       'pluralName': 'Mexican Restaurants',
#       'shortName': 'Mexican',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '559116226'},
#     'referralId': 'v-1596417410',
#     'hasPerk': False},
#    {'id': '502953dbe4b063baa21f48a5',
#     'name': 'Qdoba Mexican Grill',
#     'location': {'address': '1290 S Normal Ave, Memorial Union Building',
#      'crossStreet': 'Memorial Union Building',
#      'lat': 33.4179057,
#      'lng': -111.9342894,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.4179057,
#        'lng': -111.9342894}],
#      'distance': 209,
#      'postalCode': '85287',
#      'cc': 'US',
#      'city': 'Tempe',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['1290 S Normal Ave, Memorial Union Building (Memorial Union Building)',
#       'Tempe, AZ 85287',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c1941735',
#       'name': 'Mexican Restaurant',
#       'pluralName': 'Mexican Restaurants',
#       'shortName': 'Mexican',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1596417410',
#     'hasPerk': False},
#    {'id': '57e34445498ef020c1c11c41',
#     'name': 'Cafe Rio Mexican Grill',
#     'location': {'address': '715 S Rural Rd',
#      'crossStreet': 'at E University Dr',
#      'lat': 33.4230566449628,
#      'lng': -111.925747425442,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.4230566449628,
#        'lng': -111.925747425442}],
#      'distance': 1187,
#      'postalCode': '85281',
#      'cc': 'US',
#      'city': 'Tempe',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['715 S Rural Rd (at E University Dr)',
#       'Tempe, AZ 85281',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c1941735',
#       'name': 'Mexican Restaurant',
#       'pluralName': 'Mexican Restaurants',
#       'shortName': 'Mexican',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1747780',
#      'url': 'https://www.grubhub.com/restaurant/cafe-rio-715-s-rural-rd-tempe/1747780?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1747780',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1596417410',
#     'hasPerk': False},
#    {'id': '4e04e186b61c6b32fb0859af',
#     'name': 'Baja Fresh Mexican Grill',
#     'location': {'address': '777 S College Ave Ste 102',
#      'crossStreet': 'at University Dr.',
#      'lat': 33.42294933743883,
#      'lng': -111.9350651379263,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.42294933743883,
#        'lng': -111.9350651379263}],
#      'distance': 674,
#      'postalCode': '85281',
#      'cc': 'US',
#      'city': 'Tempe',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['777 S College Ave Ste 102 (at University Dr.)',
#       'Tempe, AZ 85281',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c1941735',
#       'name': 'Mexican Restaurant',
#       'pluralName': 'Mexican Restaurants',
#       'shortName': 'Mexican',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1596417410',
#     'hasPerk': False},
#    {'id': '4f321bed19836c91c7b6c7f3',
#     'name': "Moreno's Mexican Grill",
#     'location': {'address': '829 S Rural Rd',
#      'lat': 33.421180725097656,
#      'lng': -111.92581939697266,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.421180725097656,
#        'lng': -111.92581939697266}],
#      'distance': 1076,
#      'postalCode': '85281',
#      'cc': 'US',
#      'city': 'Tempe',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['829 S Rural Rd',
#       'Tempe, AZ 85281',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c1941735',
#       'name': 'Mexican Restaurant',
#       'pluralName': 'Mexican Restaurants',
#       'shortName': 'Mexican',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1596417410',
#     'hasPerk': False},
#    {'id': '45425ccbf964a520583c1fe3',
#     'name': "Filiberto's Mexican Food",
#     'location': {'address': '1270 E Apache Blvd',
#      'lat': 33.41509668194863,
#      'lng': -111.91802198706813,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.41509668194863,
#        'lng': -111.91802198706813}],
#      'distance': 1706,
#      'postalCode': '85281',
#      'cc': 'US',
#      'city': 'Tempe',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['1270 E Apache Blvd',
#       'Tempe, AZ 85281',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c1941735',
#       'name': 'Mexican Restaurant',
#       'pluralName': 'Mexican Restaurants',
#       'shortName': 'Mexican',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '2034464',
#      'url': 'https://www.grubhub.com/restaurant/filibertos-mexican-food-1270-e-apache-blvd-tempe/2034464?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2034464',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1596417410',
#     'hasPerk': False},
#    {'id': '4e4e672bbd4101d0d7a96417',
#     'name': 'El Penasco Mexican Kitchen',
#     'location': {'address': '19 E Broadway Rd',
#      'lat': 33.406742095947266,
#      'lng': -111.93895721435547,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.406742095947266,
#        'lng': -111.93895721435547}],
#      'distance': 1166,
#      'postalCode': '85282',
#      'cc': 'US',
#      'city': 'Tempe',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['19 E Broadway Rd',
#       'Tempe, AZ 85282',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c1941735',
#       'name': 'Mexican Restaurant',
#       'pluralName': 'Mexican Restaurants',
#       'shortName': 'Mexican',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1596417410',
#     'hasPerk': False},
#    {'id': '4feb7944e4b0bfcf14a6c99d',
#     'name': "Jesus' mexican escape",
#     'location': {'lat': 33.426713535567536,
#      'lng': -111.94471822181923,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.426713535567536,
#        'lng': -111.94471822181923}],
#      'distance': 1340,
#      'postalCode': '85281',
#      'cc': 'US',
#      'city': 'Tempe',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['Tempe, AZ 85281', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c1941735',
#       'name': 'Mexican Restaurant',
#       'pluralName': 'Mexican Restaurants',
#       'shortName': 'Mexican',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1596417410',
#     'hasPerk': False},
#    {'id': '4da3b45dd8d26a31d5ca46c8',
#     'name': 'Andale Mexican Food',
#     'location': {'address': '818 W Broadway Rd #106',
#      'lat': 33.407336,
#      'lng': -111.950181,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.407336,
#        'lng': -111.950181},
#       {'label': 'entrance', 'lat': 33.407732, 'lng': -111.950942}],
#      'distance': 1681,
#      'postalCode': '85282',
#      'cc': 'US',
#      'city': 'Tempe',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['818 W Broadway Rd #106',
#       'Tempe, AZ 85282',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c1941735',
#       'name': 'Mexican Restaurant',
#       'pluralName': 'Mexican Restaurants',
#       'shortName': 'Mexican',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1596417410',
#     'hasPerk': False},
#    {'id': '4e4e38ebbd4101d0d7a5341b',
#     'name': "Manuel's Mexican",
#     'location': {'address': '1123 W Broadway Rd',
#      'lat': 33.40687942504883,
#      'lng': -111.95619201660156,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.40687942504883,
#        'lng': -111.95619201660156}],
#      'distance': 2167,
#      'postalCode': '85282',
#      'cc': 'US',
#      'city': 'Tempe',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['1123 W Broadway Rd',
#       'Tempe, AZ 85282',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c1941735',
#       'name': 'Mexican Restaurant',
#       'pluralName': 'Mexican Restaurants',
#       'shortName': 'Mexican',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1596417410',
#     'hasPerk': False},
#    {'id': '4f32b07f19836c91c7f02131',
#     'name': "Manuel's Mexican Food",
#     'location': {'address': '1123 W Broadway Rd',
#      'lat': 33.40687942504883,
#      'lng': -111.95619201660156,
#      'labeledLatLngs': [{'label': 'entrance',
#        'lat': 33.406994,
#        'lng': -111.956118},
#       {'label': 'display',
#        'lat': 33.40687942504883,
#        'lng': -111.95619201660156}],
#      'distance': 2167,
#      'postalCode': '85282',
#      'cc': 'US',
#      'city': 'Tempe',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['1123 W Broadway Rd',
#       'Tempe, AZ 85282',
#       'United States']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1596417410',
#     'hasPerk': False},
#    {'id': '4db0f76a8154905aadb81bf8',
#     'name': "Sombrero's Mexican Grill",
#     'location': {'address': '818 W Broadway Rd',
#      'lat': 33.40775632988517,
#      'lng': -111.95094492494567,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.40775632988517,
#        'lng': -111.95094492494567},
#       {'label': 'entrance', 'lat': 33.407732, 'lng': -111.950942}],
#      'distance': 1708,
#      'postalCode': '85282',
#      'cc': 'US',
#      'city': 'Tempe',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['818 W Broadway Rd',
#       'Tempe, AZ 85282',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c1941735',
#       'name': 'Mexican Restaurant',
#       'pluralName': 'Mexican Restaurants',
#       'shortName': 'Mexican',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1596417410',
#     'hasPerk': False},
#    {'id': '4a877c64f964a520850420e3',
#     'name': "Macayo's Depot Cantina",
#     'location': {'address': '300 South Ash Avenue',
#      'lat': 33.4277376,
#      'lng': -111.94326685,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.4277376,
#        'lng': -111.94326685},
#       {'label': 'entrance', 'lat': 33.427614, 'lng': -111.943163}],
#      'distance': 1364,
#      'postalCode': '85281',
#      'cc': 'US',
#      'city': 'Tempe',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['300 South Ash Avenue',
#       'Tempe, AZ 85281',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c1941735',
#       'name': 'Mexican Restaurant',
#       'pluralName': 'Mexican Restaurants',
#       'shortName': 'Mexican',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '562742287'},
#     'referralId': 'v-1596417410',
#     'hasPerk': False},
#    {'id': '50289d28582f64b9165f3227',
#     'name': 'Rocky Point Cantina',
#     'location': {'address': '1001 E 8th St',
#      'crossStreet': 'E of Rural Rd',
#      'lat': 33.42004640993022,
#      'lng': -111.92324732497165,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.42004640993022,
#        'lng': -111.92324732497165}],
#      'distance': 1255,
#      'postalCode': '85281',
#      'cc': 'US',
#      'city': 'Tempe',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['1001 E 8th St (E of Rural Rd)',
#       'Tempe, AZ 85281',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e5931735',
#       'name': 'Music Venue',
#       'pluralName': 'Music Venues',
#       'shortName': 'Music Venue',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1596417410',
#     'hasPerk': False},
#    {'id': '4b2bd4faf964a520f5bb24e3',
#     'name': 'Pancheros',
#     'location': {'address': '555 N Scottsdale Rd Unit 105',
#      'lat': 33.4345339619378,
#      'lng': -111.92563116669241,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.4345339619378,
#        'lng': -111.92563116669241}],
#      'distance': 2189,
#      'postalCode': '85281',
#      'cc': 'US',
#      'city': 'Tempe',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['555 N Scottsdale Rd Unit 105',
#       'Tempe, AZ 85281',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c1941735',
#       'name': 'Mexican Restaurant',
#       'pluralName': 'Mexican Restaurants',
#       'shortName': 'Mexican',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '75483338'},
#     'referralId': 'v-1596417410',
#     'hasPerk': False},
#    {'id': '51e60252498ee1ce20a401fd',
#     'name': 'Costa Vida',
#     'location': {'address': '1324 S. Rural Rd.',
#      'crossStreet': 'at E Apache Blvd',
#      'lat': 33.41363120882872,
#      'lng': -111.92670673491199,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.41363120882872,
#        'lng': -111.92670673491199}],
#      'distance': 961,
#      'postalCode': '85281',
#      'cc': 'US',
#      'city': 'Tempe',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['1324 S. Rural Rd. (at E Apache Blvd)',
#       'Tempe, AZ 85281',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c1941735',
#       'name': 'Mexican Restaurant',
#       'pluralName': 'Mexican Restaurants',
#       'shortName': 'Mexican',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1596417410',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories delivery.id  \
# 0  [{'id': '4bf58dd8d48988d1c1941735', 'name': 'M...         NaN
# 1  [{'id': '4bf58dd8d48988d1c1941735', 'name': 'M...         NaN
# 2  [{'id': '4bf58dd8d48988d1c1941735', 'name': 'M...         NaN
# 3  [{'id': '4bf58dd8d48988d1c1941735', 'name': 'M...         NaN
# 4  [{'id': '4bf58dd8d48988d1c1941735', 'name': 'M...     1747780
#
#                delivery.provider.icon.name  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4  /delivery_provider_grubhub_20180129.png
#
#               delivery.provider.icon.prefix delivery.provider.icon.sizes  \
# 0                                       NaN                          NaN
# 1                                       NaN                          NaN
# 2                                       NaN                          NaN
# 3                                       NaN                          NaN
# 4  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
#
#   delivery.provider.name                                       delivery.url  \
# 0                    NaN                                                NaN
# 1                    NaN                                                NaN
# 2                    NaN                                                NaN
# 3                    NaN                                                NaN
# 4                grubhub  https://www.grubhub.com/restaurant/cafe-rio-71...
#
#    hasPerk                        id  \
# 0    False  4aa6f5a8f964a520a34b20e3
# 1    False  4ad76fe1f964a520670a21e3
# 2    False  4b6ccb12f964a520e3542ce3
# 3    False  502953dbe4b063baa21f48a5
# 4    False  57e34445498ef020c1c11c41
#
#                              location.address     ...      location.distance  \
# 0                             1038 S Mill Ave     ...                    402
# 1                         960 W University Dr     ...                   1569
# 2                     1250 West Broadway Road     ...                   2255
# 3  1290 S Normal Ave, Memorial Union Building     ...                    209
# 4                              715 S Rural Rd     ...                   1187
#
#                            location.formattedAddress  \
# 0  [1038 S Mill Ave (at W 11th St), Tempe, AZ 852...
# 1  [960 W University Dr (at Hardy Dr), Tempe, AZ ...
# 2  [1250 West Broadway Road (at S Cutler Dr), Tem...
# 3  [1290 S Normal Ave, Memorial Union Building (M...
# 4  [715 S Rural Rd (at E University Dr), Tempe, A...
#
#                              location.labeledLatLngs location.lat  \
# 0  [{'label': 'display', 'lat': 33.41798133570578...    33.417981
# 1  [{'label': 'display', 'lat': 33.42258153193346...    33.422582
# 2  [{'label': 'display', 'lat': 33.40780775, 'lng...    33.407808
# 3  [{'label': 'display', 'lat': 33.4179057, 'lng'...    33.417906
# 4  [{'label': 'display', 'lat': 33.4230566449628,...    33.423057
#
#    location.lng location.postalCode location.state  \
# 0   -111.940402               85281             AZ
# 1   -111.951739               85281             AZ
# 2   -111.957890               85282             AZ
# 3   -111.934289               85287             AZ
# 4   -111.925747               85281             AZ
#
#                          name    referralId venuePage.id
# 0      Chipotle Mexican Grill  v-1596417410          NaN
# 1  Rosita's Fine Mexican Food  v-1596417410          NaN
# 2    Filiberto's Mexican Food  v-1596417410    559116226
# 3         Qdoba Mexican Grill  v-1596417410          NaN
# 4      Cafe Rio Mexican Grill  v-1596417410          NaN
#
# [5 rows x 24 columns]

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                           name          categories  \
# 0       Chipotle Mexican Grill  Mexican Restaurant
# 1   Rosita's Fine Mexican Food  Mexican Restaurant
# 2     Filiberto's Mexican Food  Mexican Restaurant
# 3          Qdoba Mexican Grill  Mexican Restaurant
# 4       Cafe Rio Mexican Grill  Mexican Restaurant
# 5     Baja Fresh Mexican Grill  Mexican Restaurant
# 6       Moreno's Mexican Grill  Mexican Restaurant
# 7     Filiberto's Mexican Food  Mexican Restaurant
# 8   El Penasco Mexican Kitchen  Mexican Restaurant
# 9        Jesus' mexican escape  Mexican Restaurant
# 10         Andale Mexican Food  Mexican Restaurant
# 11            Manuel's Mexican  Mexican Restaurant
# 12       Manuel's Mexican Food                Food
# 13    Sombrero's Mexican Grill  Mexican Restaurant
# 14      Macayo's Depot Cantina  Mexican Restaurant
# 15         Rocky Point Cantina         Music Venue
# 16                   Pancheros  Mexican Restaurant
# 17                  Costa Vida  Mexican Restaurant
#
#                                        address  cc   city        country  \
# 0                              1038 S Mill Ave  US  Tempe  United States
# 1                          960 W University Dr  US  Tempe  United States
# 2                      1250 West Broadway Road  US  Tempe  United States
# 3   1290 S Normal Ave, Memorial Union Building  US  Tempe  United States
# 4                               715 S Rural Rd  US  Tempe  United States
# 5                    777 S College Ave Ste 102  US  Tempe  United States
# 6                               829 S Rural Rd  US  Tempe  United States
# 7                           1270 E Apache Blvd  US  Tempe  United States
# 8                             19 E Broadway Rd  US  Tempe  United States
# 9                                          NaN  US  Tempe  United States
# 10                      818 W Broadway Rd #106  US  Tempe  United States
# 11                          1123 W Broadway Rd  US  Tempe  United States
# 12                          1123 W Broadway Rd  US  Tempe  United States
# 13                           818 W Broadway Rd  US  Tempe  United States
# 14                        300 South Ash Avenue  US  Tempe  United States
# 15                               1001 E 8th St  US  Tempe  United States
# 16                555 N Scottsdale Rd Unit 105  US  Tempe  United States
# 17                           1324 S. Rural Rd.  US  Tempe  United States
#
#                 crossStreet  distance  \
# 0              at W 11th St       402
# 1               at Hardy Dr      1569
# 2            at S Cutler Dr      2255
# 3   Memorial Union Building       209
# 4        at E University Dr      1187
# 5         at University Dr.       674
# 6                       NaN      1076
# 7                       NaN      1706
# 8                       NaN      1166
# 9                       NaN      1340
# 10                      NaN      1681
# 11                      NaN      2167
# 12                      NaN      2167
# 13                      NaN      1708
# 14                      NaN      1364
# 15            E of Rural Rd      1255
# 16                      NaN      2189
# 17         at E Apache Blvd       961
#
#                                      formattedAddress  \
# 0   [1038 S Mill Ave (at W 11th St), Tempe, AZ 852...
# 1   [960 W University Dr (at Hardy Dr), Tempe, AZ ...
# 2   [1250 West Broadway Road (at S Cutler Dr), Tem...
# 3   [1290 S Normal Ave, Memorial Union Building (M...
# 4   [715 S Rural Rd (at E University Dr), Tempe, A...
# 5   [777 S College Ave Ste 102 (at University Dr.)...
# 6    [829 S Rural Rd, Tempe, AZ 85281, United States]
# 7   [1270 E Apache Blvd, Tempe, AZ 85281, United S...
# 8   [19 E Broadway Rd, Tempe, AZ 85282, United Sta...
# 9                    [Tempe, AZ 85281, United States]
# 10  [818 W Broadway Rd #106, Tempe, AZ 85282, Unit...
# 11  [1123 W Broadway Rd, Tempe, AZ 85282, United S...
# 12  [1123 W Broadway Rd, Tempe, AZ 85282, United S...
# 13  [818 W Broadway Rd, Tempe, AZ 85282, United St...
# 14  [300 South Ash Avenue, Tempe, AZ 85281, United...
# 15  [1001 E 8th St (E of Rural Rd), Tempe, AZ 8528...
# 16  [555 N Scottsdale Rd Unit 105, Tempe, AZ 85281...
# 17  [1324 S. Rural Rd. (at E Apache Blvd), Tempe, ...
#
#                                        labeledLatLngs        lat         lng  \
# 0   [{'label': 'display', 'lat': 33.41798133570578...  33.417981 -111.940402
# 1   [{'label': 'display', 'lat': 33.42258153193346...  33.422582 -111.951739
# 2   [{'label': 'display', 'lat': 33.40780775, 'lng...  33.407808 -111.957890
# 3   [{'label': 'display', 'lat': 33.4179057, 'lng'...  33.417906 -111.934289
# 4   [{'label': 'display', 'lat': 33.4230566449628,...  33.423057 -111.925747
# 5   [{'label': 'display', 'lat': 33.42294933743883...  33.422949 -111.935065
# 6   [{'label': 'display', 'lat': 33.42118072509765...  33.421181 -111.925819
# 7   [{'label': 'display', 'lat': 33.41509668194863...  33.415097 -111.918022
# 8   [{'label': 'display', 'lat': 33.40674209594726...  33.406742 -111.938957
# 9   [{'label': 'display', 'lat': 33.42671353556753...  33.426714 -111.944718
# 10  [{'label': 'display', 'lat': 33.407336, 'lng':...  33.407336 -111.950181
# 11  [{'label': 'display', 'lat': 33.40687942504883...  33.406879 -111.956192
# 12  [{'label': 'entrance', 'lat': 33.406994, 'lng'...  33.406879 -111.956192
# 13  [{'label': 'display', 'lat': 33.40775632988517...  33.407756 -111.950945
# 14  [{'label': 'display', 'lat': 33.4277376, 'lng'...  33.427738 -111.943267
# 15  [{'label': 'display', 'lat': 33.42004640993022...  33.420046 -111.923247
# 16  [{'label': 'display', 'lat': 33.4345339619378,...  33.434534 -111.925631
# 17  [{'label': 'display', 'lat': 33.41363120882872...  33.413631 -111.926707
#
#    postalCode state                        id
# 0       85281    AZ  4aa6f5a8f964a520a34b20e3
# 1       85281    AZ  4ad76fe1f964a520670a21e3
# 2       85282    AZ  4b6ccb12f964a520e3542ce3
# 3       85287    AZ  502953dbe4b063baa21f48a5
# 4       85281    AZ  57e34445498ef020c1c11c41
# 5       85281    AZ  4e04e186b61c6b32fb0859af
# 6       85281    AZ  4f321bed19836c91c7b6c7f3
# 7       85281    AZ  45425ccbf964a520583c1fe3
# 8       85282    AZ  4e4e672bbd4101d0d7a96417
# 9       85281    AZ  4feb7944e4b0bfcf14a6c99d
# 10      85282    AZ  4da3b45dd8d26a31d5ca46c8
# 11      85282    AZ  4e4e38ebbd4101d0d7a5341b
# 12      85282    AZ  4f32b07f19836c91c7f02131
# 13      85282    AZ  4db0f76a8154905aadb81bf8
# 14      85281    AZ  4a877c64f964a520850420e3
# 15      85281    AZ  50289d28582f64b9165f3227
# 16      85281    AZ  4b2bd4faf964a520f5bb24e3
# 17      85281    AZ  51e60252498ee1ce20a401fd

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
